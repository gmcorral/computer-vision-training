# %% [markdown]
# ![MLA Logo](https://drive.corp.amazon.com/view/mrruckma@/MLA_headerv2.png?download=true)

# %% [markdown]
# #### In this example, we will use Transfer Learning. A pre-trained Alexnet is used to classify five image categories. You can see in the training loop that it only takes 5 epochs to reach the 98% validation accuracy.

# %% [markdown]
# ### 1. Download and Read the Dataset
#
# #### We have the following classes:
# ### * Class 0: Inconclusive
# ### * Class 1: Two wheels
# ### * Class 2: Four wheels
# ### * Class 3: Not luggage
# ### * Class 4: Zero wheels

# %% [markdown]
# Let's download the dataset from our S3 bucket into Eider.

# %%
#!pip install -U scikit-image
#!pip install -U numpy

#Let's read in our training data. ASINs correspond to those in Leaderboard's ID.
import pandas as pd
import boto3

df = pd.read_pickle("./training_data.pkl")
tf = pd.read_pickle("./test_data.pkl")

# %%
df.head()

# %% [markdown]
# #### Let's look at some examples. The first column of the numpy array holds images and second column keeps the class information.

# %%
import matplotlib.pyplot as plt

classes = ['inconclusive', '2-wheel', '4-wheel', 'not-luggage', '0-wheel']

plt.imshow(df["data"][551])
plt.title(classes[df["label"][551]])
plt.axis("off")
plt.show()

plt.imshow(df["data"][1119])
plt.title(classes[df["label"][1119]])
plt.axis("off")
plt.show()

plt.imshow(df["data"][156])
plt.title(classes[df["label"][156]])
plt.axis("off")
plt.show()

plt.imshow(df["data"][1526])
plt.title(classes[df["label"][1526]])
plt.axis("off")
plt.show()

plt.imshow(df["data"][15])
plt.title(classes[df["label"][15]])
plt.axis("off")
plt.show()

# %% [markdown]
# ### 2a. Resample data
# #### * Balance classes by upsampling
# #### * Data augmentation

# %%
from sklearn.utils import resample
from sklearn.utils import shuffle
import random
import skimage as sk
from skimage import transform
from skimage import util
import numpy as np
 
# Rotate the image with a given angle
def rotate_image(image_array, angle):
    # we will fill 1s (white) for the areas outside of image boundaries
    return sk.transform.rotate(image_array, angle, cval=1)
 
# Add random noise to image
def random_noise(image_array):
    return sk.util.random_noise(image_array)
    
# Flip the image at a given axis
def image_flip(image_array, axis):
    # axis=0 => vertical flip
    # axis=1 => horizontal flip
    return np.flip(image_array, axis=axis)

def augment_dataset(ds):
    
    # apply random operations to dataset
    for i, im in enumerate(ds['data'].values):
        
        # values over 2 do nothing: affect 75% of images
        op = random.randint(0, 2)
        if op == 0:
            ds['data'].values[i] = rotate_image(im, random.randint(-20, 20))
        elif op == 1:
            ds['data'].values[i] = random_noise(im)
        elif op == 2:
            ds['data'].values[i] = image_flip(im, random.randint(0, 1))
        else:
            pass
    
def upsample(df):
    
    class_0 = df.loc[df['label'] == 0]
    class_1 = df.loc[df['label'] == 1]
    class_2 = df.loc[df['label'] == 2]
    class_3 = df.loc[df['label'] == 3]
    class_4 = df.loc[df['label'] == 4]

    upsampled_class_0 = resample(class_0, 
                                 replace=True, # sample with replacement
                                 n_samples=len(class_1), # upsample to match class 3
                                 random_state=123 # reproducible result
                                )
    upsampled_class_1 = resample(class_1, 
                                 replace=True, # sample with replacement
                                 n_samples=len(class_1), # upsample to match class 3
                                 random_state=123 # reproducible result
                                )
    upsampled_class_2 = resample(class_2, 
                                 replace=True, # sample with replacement
                                 n_samples=len(class_1), # upsample to match class 3
                                 random_state=123 # reproducible result
                                )
    upsampled_class_3 = resample(class_3, 
                                 replace=True, # sample with replacement
                                 n_samples=len(class_1), # upsample to match class 3
                                 random_state=123 # reproducible result
                                )
    upsampled_class_4 = resample(class_4, 
                                 replace=True, # sample with replacement
                                 n_samples=len(class_1), # upsample to match class 3
                                 random_state=123 # reproducible result
                                )

    augment_dataset(upsampled_class_0)
    #augment_dataset(upsampled_class_1)
    #augment_dataset(upsampled_class_2)
    #augment_dataset(upsampled_class_3)
    augment_dataset(upsampled_class_4)
    
    df_upsampled = pd.concat([upsampled_class_0, 
                              class_1,
                              class_2,
                              class_3,
                              upsampled_class_4,
                             ])

    # We put all records in order by their class, let's shuffle everything
    return shuffle(df_upsampled)

# %% [markdown]
# ### 2b. Split the dataset and Process Images
# #### * We split the original dataset into Training (80%), Validation (10%) and Test (10%) subsets.
# #### * We will process images by resizing to 224x224 and converting (row, column, channel) to (channel, row, column)

# %%
import numpy as np
from skimage.transform import resize

# Let's split to data into training (80%), validation (10%) and test (10%) subsets.
df = shuffle(df)
tr_pct=0.90

train_indices = np.arange(0, int(tr_pct*len(df)))
val_indices = np.arange(int(tr_pct*len(df)), int(len(df)))
test_indices = np.arange(0, len(tf))

train_df = upsample(df.iloc[train_indices])
val_df = df.iloc[val_indices]
test_df = tf.iloc[test_indices]

del df
del tf

def getImages(images):
    # Create the image holder array
    image_arr = np.zeros((images.shape[0], 3, 224, 224))
    
    # Iterate through the image data
    for i, im in enumerate(images):
        # Get image from the data column of the current row
        
        # We need a fixed size input, our images have different sizes, let's pick 224x224.
        # Resize image below
        im = resize(im, output_shape=(224, 224))
        
        # Gluon/mxnet expects images in this format (channel, row, column)
        # This is the opposite of (row, column, channel), let's fix it
        im = np.moveaxis(im, -1, 0)
        
        # Assign the value in the image array
        image_arr[i] = im

    return image_arr
    
train_images, train_labels = getImages(train_df["data"].values), train_df["label"].values
validation_images, validation_labels = getImages(val_df["data"].values), val_df["label"].values

# %%
import matplotlib.pyplot as plt
import seaborn as sb

plt.figure()
ax = sb.countplot(x=train_labels, y = None)
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate(y, (x.mean(), y), ha='center', va='bottom') 
plt.xticks(rotation=60)
plt.title('Number of records in each class')
plt.show()

# %% [markdown]
# ### 3. Build the Convolutional Neural Network
# * We will use two Convolution-Pooling pairs
# * Flatten after them
# * A fully connected layer
# * Dense output layer

# %%
from mxnet.gluon.model_zoo import vision
import mxnet as mx

def build_network(num_outputs, freeze_layers):
    # Set this to GPU or CPU
    ctx = mx.gpu()
    #ctx = mx.cpu()

    # Get the pre-trained network
    pre_trained_net = vision.resnet50_v2(pretrained=True, ctx=ctx)

    # Get the non-trained network
    net = vision.resnet50_v2(classes=num_outputs, ctx=ctx)
    
    # Initialize weights
    net.collect_params().initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
    
    # Copy weights from the trained network
    net.features = pre_trained_net.features

    # freeze conv layers
    for param in net.collect_params().values():
        if freeze_layers and not ("batchnorm2" in param.name or "dense0" in param.name):
            param.grad_req = 'null'
        print(param, param.grad_req)
            
    return net

# %% [markdown]
# ### 4. Construct the confusion matrix plot function
# #### We will use this function to plot our confusion matrix at the end of each epoch. (Epoch: One full pass through our dataset)

# %% [markdown]
# Let's write a function to plot a confusion matrix to see class-specific performance after each epoch

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    df_cm = pd.DataFrame(cm, index = [i for i in classes], columns = [i for i in classes])
    plt.figure(figsize = (5, 5))
    plt.title('Validation Confusion Matrix')
    sn.heatmap(df_cm, annot=True)
    plt.show()

# %% [markdown]
# ### 5. Training the network
# #### Let's put the training data in the MXnet format and start training. Summarizing our steps:
# #### * Select the correct compute type cpu or gpu
# #### * Split the dataset into training, validation and test splits
# #### * Create Gluon-specific data loaders
# #### * Create the network and training algorithm
# #### * Loop through dataset. We have only 5 epochs thaks to pre-trained network. We will train with training dataset and validate with the validation dataset.

# %%
import numpy as np
from mxnet import gluon, autograd, ndarray
import mxnet as mx
import mxnet.ndarray as nd
from mxnet.gluon.loss import SoftmaxCrossEntropyLoss
from sklearn.metrics import accuracy_score

# Set this to GPU or CPU 
ctx = mx.gpu()
#ctx = mx.cpu()

# Set params
batch_size = 32
epochs = 5
learning_rate = 0.001
momentum = 0.9
wd = 0.001
eps = 1e-8
optimizer = 'adagrad'

# ------ Create Network and Training Logic -------- #

# Create the network. We have 5 classes
num_outputs = 5

net = build_network(num_outputs, False)

# Define loss and trainer.
softmax_cross_etropy_loss = gluon.loss.SoftmaxCrossEntropyLoss()
trainer = gluon.Trainer(net.collect_params(), optimizer, {
    'learning_rate': learning_rate,
    #'momentum': momentum,
    'wd': wd,
    'eps': eps
})
# ------------------------------------------------- #

for epoch in range(epochs):
    
    # training loop (with autograd and trainer steps, etc.)
    cumulative_train_loss = 0
    train_predictions = []
    for i in range(0, train_images.shape[0], batch_size):
        data = nd.array(train_images[i:i + batch_size].astype('float32')).as_in_context(ctx)
        label = nd.array(train_labels[i:i + batch_size]).as_in_context(ctx)

        with autograd.record():
            output = net(data)
            train_predictions = train_predictions + np.argmax(output.asnumpy(), axis=1).tolist()
            loss = softmax_cross_etropy_loss(output, label)
            cumulative_train_loss = cumulative_train_loss + nd.sum(loss)
        loss.backward()
        trainer.step(data.shape[0])
        
    train_loss = cumulative_train_loss/len(train_images)

    # validation loop
    cumulative_valid_loss = 0
    val_predictions = []
    for i in range(0, validation_images.shape[0], batch_size):
        data = nd.array(validation_images[i:i + batch_size].astype('float32')).as_in_context(ctx)
        label = nd.array(validation_labels[i:i + batch_size]).as_in_context(ctx)
        output = net(data)
        val_predictions = val_predictions + np.argmax(output.asnumpy(), axis=1).tolist()
        val_loss = softmax_cross_etropy_loss(output, label)
        cumulative_valid_loss = cumulative_valid_loss + nd.sum(val_loss)
        
    valid_loss = cumulative_valid_loss/len(validation_images)
    
    # Calculate training and validation accuracies
    train_accuracy = accuracy_score(train_labels, train_predictions)
    validation_accuracy = accuracy_score(validation_labels, val_predictions)
    
    # Print the summary and plot the confusion matrix after each epoch
    print("Epoch {}, training loss: {:.2f}, validation loss: {:.2f}, training accuracy: {:.2f}, validation accuracy: {:.2f}".format(epoch, train_loss.asnumpy()[0], valid_loss.asnumpy()[0], train_accuracy, validation_accuracy))
    plot_confusion_matrix(validation_labels, val_predictions)
# Out:
# Parameter resnetv20_batchnorm0_gamma (shape=(3,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_batchnorm0_beta (shape=(3,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_batchnorm0_running_mean (shape=(3,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_batchnorm0_running_var (shape=(3,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_conv0_weight (shape=(64, 3, 7, 7), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_batchnorm1_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_batchnorm1_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_batchnorm1_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_batchnorm1_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm0_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm0_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm0_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm0_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv0_weight (shape=(64, 64, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm1_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm1_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm1_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm1_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv1_weight (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm2_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm2_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm2_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm2_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv2_weight (shape=(256, 64, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_conv3_weight (shape=(256, 64, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm3_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm3_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm3_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm3_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv4_weight (shape=(64, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm4_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm4_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm4_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm4_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv5_weight (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm5_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm5_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm5_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm5_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv6_weight (shape=(256, 64, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm6_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm6_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm6_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm6_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv7_weight (shape=(64, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm7_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm7_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm7_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm7_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv8_weight (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm8_gamma (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm8_beta (shape=(64,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage1_batchnorm8_running_mean (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_batchnorm8_running_var (shape=(64,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage1_conv9_weight (shape=(256, 64, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm0_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm0_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm0_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm0_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv0_weight (shape=(128, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm1_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm1_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm1_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm1_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv1_weight (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm2_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm2_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm2_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm2_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv2_weight (shape=(512, 128, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_conv3_weight (shape=(512, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm3_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm3_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm3_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm3_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv4_weight (shape=(128, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm4_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm4_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm4_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm4_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv5_weight (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm5_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm5_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm5_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm5_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv6_weight (shape=(512, 128, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm6_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm6_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm6_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm6_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv7_weight (shape=(128, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm7_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm7_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm7_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm7_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv8_weight (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm8_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm8_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm8_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm8_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv9_weight (shape=(512, 128, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm9_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm9_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm9_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm9_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv10_weight (shape=(128, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm10_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm10_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm10_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm10_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv11_weight (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm11_gamma (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm11_beta (shape=(128,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage2_batchnorm11_running_mean (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_batchnorm11_running_var (shape=(128,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage2_conv12_weight (shape=(512, 128, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm0_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm0_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm0_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm0_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv0_weight (shape=(256, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm1_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm1_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm1_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm1_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv1_weight (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm2_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm2_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm2_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm2_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv2_weight (shape=(1024, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_conv3_weight (shape=(1024, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm3_gamma (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm3_beta (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm3_running_mean (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm3_running_var (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv4_weight (shape=(256, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm4_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm4_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm4_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm4_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv5_weight (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm5_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm5_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm5_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm5_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv6_weight (shape=(1024, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm6_gamma (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm6_beta (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm6_running_mean (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm6_running_var (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv7_weight (shape=(256, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm7_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm7_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm7_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm7_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv8_weight (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm8_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm8_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm8_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm8_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv9_weight (shape=(1024, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm9_gamma (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm9_beta (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm9_running_mean (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm9_running_var (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv10_weight (shape=(256, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm10_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm10_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm10_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm10_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv11_weight (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm11_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm11_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm11_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm11_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv12_weight (shape=(1024, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm12_gamma (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm12_beta (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm12_running_mean (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm12_running_var (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv13_weight (shape=(256, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm13_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm13_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm13_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm13_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv14_weight (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm14_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm14_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm14_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm14_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv15_weight (shape=(1024, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm15_gamma (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm15_beta (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm15_running_mean (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm15_running_var (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv16_weight (shape=(256, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm16_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm16_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm16_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm16_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv17_weight (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm17_gamma (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm17_beta (shape=(256,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage3_batchnorm17_running_mean (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_batchnorm17_running_var (shape=(256,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage3_conv18_weight (shape=(1024, 256, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm0_gamma (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm0_beta (shape=(1024,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm0_running_mean (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm0_running_var (shape=(1024,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv0_weight (shape=(512, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm1_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm1_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm1_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm1_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv1_weight (shape=(512, 512, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm2_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm2_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm2_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm2_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv2_weight (shape=(2048, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_conv3_weight (shape=(2048, 1024, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm3_gamma (shape=(2048,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm3_beta (shape=(2048,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm3_running_mean (shape=(2048,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm3_running_var (shape=(2048,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv4_weight (shape=(512, 2048, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm4_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm4_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm4_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm4_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv5_weight (shape=(512, 512, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm5_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm5_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm5_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm5_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv6_weight (shape=(2048, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm6_gamma (shape=(2048,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm6_beta (shape=(2048,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm6_running_mean (shape=(2048,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm6_running_var (shape=(2048,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv7_weight (shape=(512, 2048, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm7_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm7_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm7_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm7_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv8_weight (shape=(512, 512, 3, 3), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm8_gamma (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm8_beta (shape=(512,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_stage4_batchnorm8_running_mean (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_batchnorm8_running_var (shape=(512,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_stage4_conv9_weight (shape=(2048, 512, 1, 1), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_batchnorm2_gamma (shape=(2048,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_batchnorm2_beta (shape=(2048,), dtype=<class 'numpy.float32'>) write
# Parameter resnetv20_batchnorm2_running_mean (shape=(2048,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv20_batchnorm2_running_var (shape=(2048,), dtype=<class 'numpy.float32'>) null
# Parameter resnetv21_dense0_weight (shape=(5, 2048), dtype=float32) write
# Parameter resnetv21_dense0_bias (shape=(5,), dtype=float32) write
# Epoch 0, training loss: 0.32, validation loss: 0.53, training accuracy: 0.88, validation accuracy: 0.81
# Epoch 1, training loss: 0.02, validation loss: 0.59, training accuracy: 1.00, validation accuracy: 0.81
# Epoch 2, training loss: 0.00, validation loss: 0.61, training accuracy: 1.00, validation accuracy: 0.81
# Epoch 3, training loss: 0.00, validation loss: 0.64, training accuracy: 1.00, validation accuracy: 0.81
# Epoch 4, training loss: 0.00, validation loss: 0.65, training accuracy: 1.00, validation accuracy: 0.81

# %% [markdown]
# ### 6. Testing the network
# #### Now, it is time to test our network on the test set.
# #### __Important Note:__ For your final project, you will get the test set from an S3 bucket, here we are using the test subset we already created. You don't need to create this test subset for your final project (just read it from the s3 bucket).
# #### We will do something similar to the validation loop above

# %%
test_images = getImages(test_df["data"].values)
test_predictions = []
for i in range(0, test_images.shape[0], batch_size):
    data = nd.array(test_images[i:i + batch_size].astype('float32')).as_in_context(ctx)
    output = net(data)
    test_predictions = test_predictions + np.argmax(output.asnumpy(), axis=1).tolist()
print(test_predictions)

# %% [markdown]
# #### Let's print the first 10 predictions (0: Ring, 1: Shirt, 2: Watch, 3: Jeans, 4: Shoe) and the first 10 images.
# #### If you remember, we changed image data order from (row, col, channel) to (channel, row, col), we will revert those changes to plot our images

# %%
import pandas as pd

result_df = pd.DataFrame(columns=['ID', 'label'])
result_df["ID"] = test_df["ID"]
result_df["label"] = test_predictions

result_df.to_csv("./results-transfer-resnet-aug-1.csv", index=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 16))

for i in range(0, 10):
    plt.subplot(5, 5, i+1)
    im = test_images[i]
    label = test_predictions[i]
    im = np.moveaxis(im, 0, 2)
    plt.title(classes[label])
    plt.imshow(im)
    plt.axis("off")
